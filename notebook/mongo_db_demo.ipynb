# %%
print("ok")
# Out:
# ok

# %%
"""
mongodb+srv://nawghare0:ht4PBkERKNMpQNBx@cluster0.s4ruq.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0
"""

# %%
import pandas as pd

# %%
df = pd.read_csv('Churndata.csv')
df.head()
# Out:
#    gender  age married  number_of_dependents          city  zip_code  \
# 0  Female   37     Yes                     0  Frazier Park     93225
# 1    Male   46      No                     0      Glendale     91206
# 2    Male   50      No                     0    Costa Mesa     92627
# 3    Male   78     Yes                     0      Martinez     94553
# 4  Female   75     Yes                     0     Camarillo     93010
#
#     latitude   longitude  number_of_referrals  tenure_in_months  ...  \
# 0  34.827662 -118.999073                    2                 9  ...
# 1  34.162515 -118.203869                    0                 9  ...
# 2  33.645672 -117.922613                    0                 4  ...
# 3  38.014457 -122.115432                    1                13  ...
# 4  34.227846 -119.079903                    3                 3  ...
#
#          contract  paperless_billing   payment_method monthly_charge  \
# ...

# %%
df.shape
# Out:
# (7043, 34)

# %%
data = df.to_dict(orient='records')
data
# Out:
# [{'gender': 'Female',
#   'age': 37,
#   'married': 'Yes',
#   'number_of_dependents': 0,
#   'city': 'Frazier Park',
#   'zip_code': 93225,
#   'latitude': 34.827662,
#   'longitude': -118.999073,
#   'number_of_referrals': 2,
#   'tenure_in_months': 9,
#   'phone_service': 'Yes',
#   'avg_monthly_long_distance_charges': 42.39,
#   'multiple_lines': 'No',
#   'internet_service': 'Yes',
#   'internet_type': 'Cable',
#   'avg_monthly_gb_download': 16.0,
#   'online_security': 'No',
#   'online_backup': 'Yes',
#   'device_protection_plan': 'No',
#   'premium_tech_support': 'Yes',
#   'streaming_tv': 'Yes',
#   'streaming_movies': 'No',
#   'streaming_music': 'No',
#   'unlimited_data': 'Yes',
#   'contract': 'One Year',
#   'paperless_billing': 'Yes',
#   'payment_method': 'Credit Card',
#   'monthly_charge': 65.6,
#   'total_charges': 593.3,
#   'total_refunds': 0.0,
#   'total_extra_data_charges': 0,
#   'total_long_distance_charges': 381.51,
#   'total_revenue': 974.81,
# ...

# %%
len(data)
# Out:
# 7043

# %%
DB_NAME = 'Churn_Prediction'
COLLECTION_NAME = 'customerdata'
CONNECTION_URL = 'mongodb+srv://nawghare0:ht4PBkERKNMpQNBx@cluster0.s4ruq.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0'

# %%
import pymongo

# %%
client = pymongo.MongoClient(CONNECTION_URL)
data_base = client[DB_NAME]
collection = data_base[COLLECTION_NAME]

rec = collection.insert_many(data)

# %%
# Viewing the top 4 records
records = collection.find()
i = 0
for i,j in enumerate(records):
    if i<4:
        print(f"{i}:{j}")
        i+=1
# Out:
# 0:{'_id': ObjectId('67c739c16607708788f14b6c'), 'gender': 'Male', 'age': 54, 'married': 'No', 'number_of_dependents': 0, 'city': 'Calistoga', 'zip_code': 94515, 'latitude': 38.629618, 'longitude': -122.593216, 'number_of_referrals': 0, 'tenure_in_months': 1, 'phone_service': 'Yes', 'avg_monthly_long_distance_charges': 42.95, 'multiple_lines': 'No', 'internet_service': 'Yes', 'internet_type': 'DSL', 'avg_monthly_gb_download': 9.0, 'online_security': 'No', 'online_backup': 'No', 'device_protection_plan': 'No', 'premium_tech_support': 'No', 'streaming_tv': 'No', 'streaming_movies': 'No', 'streaming_music': 'No', 'unlimited_data': 'Yes', 'contract': 'Month-to-Month', 'paperless_billing': 'Yes', 'payment_method': 'Credit Card', 'monthly_charge': 44.3, 'total_charges': 44.3, 'total_refunds': 0.0, 'total_extra_data_charges': 0, 'total_long_distance_charges': 42.95, 'total_revenue': 87.25, 'customer_status': 'Joined'}
# ...

# %%
# Load data in the form of dataframe
loaded_data = pd.DataFrame(list(collection.find()))
loaded_data.head()
# Out:
#                         _id  gender  age married  number_of_dependents  \
# 0  67c739c16607708788f14b6c    Male   54      No                     0
# 1  67c739c16607708788f14b76    Male   66     Yes                     0
# 2  67c739c16607708788f14b7d    Male   71     Yes                     1
# 3  67c739c16607708788f14b8f  Female   76      No                     0
# 4  67c739c16607708788f14bee  Female   57      No                     0
#
#              city  zip_code   latitude   longitude  number_of_referrals  ...  \
# 0       Calistoga     94515  38.629618 -122.593216                    0  ...
# 1      Wilmington     90744  33.782068 -118.262263                    3  ...
# 2  Morongo Valley     92256  34.097863 -116.594561                    9  ...
# 3    Santa Monica     90403  34.031529 -118.491156                    0  ...
# 4         Parlier     93648  36.622237 -119.521126                    0  ...
#
#          contract paperless_billing   payment_method monthly_charge  \
# ...

# %%
loaded_data.shape
# Out:
# (7043, 35)

# %%
# Drop '_id' column
if "_id" in loaded_data.columns.to_list():
    loaded_data = loaded_data.drop(columns=['_id'], axis=1)

loaded_data.head()
# Out:
#    gender  age married  number_of_dependents            city  zip_code  \
# 0    Male   54      No                     0       Calistoga     94515
# 1    Male   66     Yes                     0      Wilmington     90744
# 2    Male   71     Yes                     1  Morongo Valley     92256
# 3  Female   76      No                     0    Santa Monica     90403
# 4  Female   57      No                     0         Parlier     93648
#
#     latitude   longitude  number_of_referrals  tenure_in_months  ...  \
# 0  38.629618 -122.593216                    0                 1  ...
# 1  33.782068 -118.262263                    3                70  ...
# 2  34.097863 -116.594561                    9                32  ...
# 3  34.031529 -118.491156                    0                44  ...
# 4  36.622237 -119.521126                    0                35  ...
#
#          contract  paperless_billing   payment_method monthly_charge  \
# ...
